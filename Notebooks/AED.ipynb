# %%
import pandas as pd

# %%
game_path = 'C:/Users/Administrador/Desktop/Game/Data/Video_Games_Sales_as_at_22_Dec_2016.csv'
data = pd.read_csv(game_path, sep= ',')

# %%
data
# Out:
#                                 Name Platform  Year_of_Release         Genre  \
# 0                         Wii Sports      Wii           2006.0        Sports
# 1                  Super Mario Bros.      NES           1985.0      Platform
# 2                     Mario Kart Wii      Wii           2008.0        Racing
# 3                  Wii Sports Resort      Wii           2009.0        Sports
# 4           Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# ...                              ...      ...              ...           ...
# 16714  Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# 16715               LMA Manager 2007     X360           2006.0        Sports
# 16716        Haitaka no Psychedelica      PSV           2016.0     Adventure
# 16717               Spirits & Spells      GBA           2003.0      Platform
# 16718            Winning Post 8 2016      PSV           2016.0    Simulation
#
# ...

# %% [markdown]
# ## Estado de salud del DataFrame

# %%
from funpymodeling import status, freq_tbl

status(data)
# Out:
#            variable  q_nan     p_nan  q_zeros   p_zeros  unique     type
# 0              Name      2  0.000120        0  0.000000   11562   object
# 1          Platform      0  0.000000        0  0.000000      31   object
# 2   Year_of_Release    269  0.016089        0  0.000000      39  float64
# 3             Genre      2  0.000120        0  0.000000      12   object
# 4         Publisher     54  0.003230        0  0.000000     581   object
# 5          NA_Sales      0  0.000000     4511  0.269813     402  float64
# 6          EU_Sales      0  0.000000     5874  0.351337     307  float64
# 7          JP_Sales      0  0.000000    10515  0.628925     244  float64
# 8       Other_Sales      0  0.000000     6604  0.395000     155  float64
# 9      Global_Sales      0  0.000000        0  0.000000     629  float64
# 10     Critic_Score   8582  0.513308        0  0.000000      82  float64
# 11     Critic_Count   8582  0.513308        0  0.000000     106  float64
# ...

# %% [markdown]
# ## Variables numericas

# %%
data.hist(figsize=(15, 15))
# Out:
# array([[<Axes: title={'center': 'Year_of_Release'}>,
#         <Axes: title={'center': 'NA_Sales'}>,
#         <Axes: title={'center': 'EU_Sales'}>],
#        [<Axes: title={'center': 'JP_Sales'}>,
#         <Axes: title={'center': 'Other_Sales'}>,
#         <Axes: title={'center': 'Global_Sales'}>],
#        [<Axes: title={'center': 'Critic_Score'}>,
#         <Axes: title={'center': 'Critic_Count'}>,
#         <Axes: title={'center': 'User_Count'}>]], dtype=object)

# %%
sns.histplot(data['Global_Sales'].dropna(), bins=30, kde=True)
plt.title('Distribucion de ventas globales')
plt.show()
# Out:
# c:\Users\Administrador\Desktop\Game\venv_games\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Variables categoricas

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x='Platform', data=data, order=data['Platform'].value_counts().index)
plt.show()

# %%
freq_tbl(data.Platform)
# Out:
#    Platform  frequency  percentage  cumulative_perc
# 0       PS2       2161    0.129254         0.129254
# 1        DS       2152    0.128716         0.257970
# 2       PS3       1331    0.079610         0.337580
# 3       Wii       1320    0.078952         0.416532
# 4      X360       1262    0.075483         0.492015
# 5       PSP       1209    0.072313         0.564328
# 6        PS       1197    0.071595         0.635923
# 7        PC        974    0.058257         0.694180
# 8        XB        824    0.049285         0.743466
# 9       GBA        822    0.049166         0.792631
# 10       GC        556    0.033256         0.825887
# 11      3DS        520    0.031102         0.856989
# 12      PSV        432    0.025839         0.882828
# 13      PS4        393    0.023506         0.906334
# 14      N64        319    0.019080         0.925414
# 15     XOne        247    0.014774         0.940188
# 16     SNES        239    0.014295         0.954483
# ...

# %%
plt.figure(figsize=(15, 6))
sns.countplot(x='Genre', data=data, order=data['Genre'].value_counts().index)
plt.show()

# %% [markdown]
# #### Analisis cuantitativo

# %%
freq_tbl(data.Genre)
# Out:
#            Genre  frequency  percentage  cumulative_perc
# 0         Action       3370    0.201567         0.201591
# 1         Sports       2348    0.140439         0.342047
# 2           Misc       1750    0.104671         0.446731
# 3   Role-Playing       1500    0.089718         0.536460
# 4        Shooter       1323    0.079132         0.615601
# 5      Adventure       1303    0.077935         0.693545
# 6         Racing       1249    0.074705         0.768260
# 7       Platform        888    0.053113         0.821379
# 8     Simulation        874    0.052276         0.873662
# 9       Fighting        849    0.050781         0.924448
# 10      Strategy        683    0.040852         0.965305
# 11        Puzzle        580    0.034691         1.000000

# %% [markdown]
# #### Ventas globales vs Plataforma

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data= data, x="Platform", y="Global_Sales")
plt.xticks(rotation=45)
plt.title('Distribucion de ventas globales por plataforma')
plt.show()

# %% [markdown]
# #### ventas globales vs Genero

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data=data, x="Genre", y="Global_Sales")
plt.xticks(rotation=45)
plt.title("Ventas Globales por Genero")
plt.show()

# %% [markdown]
# #### Ventas globales vs Ventas regionales

# %%
correlacion = data[['Global_Sales', 'NA_Sales', 'EU_Sales', 'JP_Sales', 'Other_Sales']].corr()

plt.figure(figsize=(10, 8))
sns.heatmap(correlacion, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlacion entre ventas por regiones y ventas globales')
plt.show()
